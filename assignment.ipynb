# %%
#from sklearn import datasets
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("data_sets/the_office_episodes.csv")
df2 = pd.read_csv("data_sets/the_office_series.csv")

# %%
df1 = df1.rename(columns={'title': 'EpisodeTitle'})
df1
# Out:
#      season  episode_num_in_season  episode_num_overall      EpisodeTitle  \
# 0         1                      1                    1             Pilot
# 1         1                      2                    2     Diversity Day
# 2         1                      3                    3       Health Care
# 3         1                      4                    4      The Alliance
# 4         1                      5                    5        Basketball
# ..      ...                    ...                  ...               ...
# 196       9                     21                  197  Livin' the Dream
# 197       9                     22                  198          A.A.R.M.
# 198       9                     23                  199          A.A.R.M.
# 199       9                     24                  200            Finale
# 200       9                     25                  201            Finale
#
#          directed_by                                         written_by  \
# ...

# %%
df2
# Out:
#      Unnamed: 0  Season      EpisodeTitle  \
# 0             0       1             Pilot
# 1             1       1     Diversity Day
# 2             2       1       Health Care
# 3             3       1      The Alliance
# 4             4       1        Basketball
# ..          ...     ...               ...
# 183         183       9     Stairmageddon
# 184         184       9    Paper Airplane
# 185         185       9  Livin' the Dream
# 186         186       9          A.A.R.M.
# 187         187       9            Finale
#
#                                                  About  Ratings  Votes  \
# 0    The premiere episode introduces the boss and s...      7.5   4936
# 1    Michael's off color remark puts a sensitivity ...      8.3   4801
# 2    Michael leaves Dwight in charge of picking the...      7.8   4024
# 3    Just for a laugh, Jim agrees to an alliance wi...      8.1   3915
# 4    Michael and his staff challenge the warehouse ...      8.4   4294
# ...

# %%
ratings = df2.loc[:, ["EpisodeTitle","Ratings"]]
#ratings
merged_df = df1.merge(ratings, on='EpisodeTitle')
merged_df
# Out:
#      season  episode_num_in_season  episode_num_overall      EpisodeTitle  \
# 0         1                      1                    1             Pilot
# 1         1                      2                    2     Diversity Day
# 2         1                      3                    3       Health Care
# 3         1                      4                    4      The Alliance
# 4         1                      5                    5        Basketball
# ..      ...                    ...                  ...               ...
# 196       9                     21                  197  Livin' the Dream
# 197       9                     22                  198          A.A.R.M.
# 198       9                     23                  199          A.A.R.M.
# 199       9                     24                  200            Finale
# 200       9                     25                  201            Finale
#
#          directed_by                                         written_by  \
# ...

# %%
sns.set_theme(style="darkgrid")

# Plot the responses for different events and regions
sns.lineplot(data=merged_df, x="episode_num_in_season", y="Ratings",hue="season");

# %%
#sns.scatterplot(data=df, x="flipper_length_mm", y="bill_length_mm", hue="sex")
#sns.displot(data=data2, x="flipper_length_mm", hue="species", multiple="stack");
#sns.kdeplot(data=data2, x="flipper_length_mm", hue="species", multiple="stack");

sns.scatterplot(data=merged_df, x="episode_num_overall", y="Ratings", hue="season", palette="viridis");

# %%
unique_values_count = merged_df['directed_by'].unique()
unique_values_count
# Out:
# array(['Ken Kwapis', 'Ken Whittingham', 'Bryan Gordon', 'Greg Daniels',
#        'Amy Heckerling', 'Paul Feig', 'Charles McDougall',
#        'Dennie Gordon', 'Victor Nelli, Jr.', 'Roger Nygard',
#        'Randall Einhorn', 'Miguel Arteta', 'Tucker Gates',
#        'Jeffrey Blitz', 'Harold Ramis', 'Julian Farino', 'Joss Whedon',
#        'J. J. Abrams', 'Craig Zisk', 'Paul Lieberstein', 'Jason Reitman',
#        'Jennifer Celotta', 'David Rogers', 'Stephen Merchant',
#        'Dean Holland', 'Asaad Kelada', 'Gene Stupnitsky', 'Steve Carell',
#        'Brent Forrester', 'Lee Eisenberg', 'Reggie Hudlin', 'Seth Gordon',
#        'B. J. Novak', 'John Krasinski', 'Marc Webb', 'Matt Sohn',
#        'Mindy Kaling', 'Rainn Wilson', 'John Stuart Scott',
#        'Alex Hardcastle', 'Danny Leiner', 'Michael Spiller',
#        'Troy Miller', 'Charlie Grandy', 'Ed Helms', 'Eric Appel',
#        'Brian Baumgartner', 'Claire Scanlon', 'Daniel Chun',
# ...

# %%
plt.figure(figsize=(20, 6))
plt.xticks(rotation=90)
sns.countplot(merged_df, x="directed_by");

# %%
f, ax = plt.subplots(figsize=(20, 5))
#sns.despine(f)
plt.xticks(rotation=90)

sns.histplot(
    merged_df,
    x="directed_by", hue="season",
    multiple="stack",
    palette="viridis",
    edgecolor=".3",
    linewidth=.5,
);

# %%
f, ax = plt.subplots(figsize=(20, 5))
#sns.despine(f)
plt.xticks(rotation=90)

sns.histplot(
    merged_df,
    x="written_by", hue="season",
    multiple="stack",
    palette="viridis",
    edgecolor=".3",
    linewidth=.5,
);

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(15,15))
plt.pie(merged_df['us_viewers'], labels=df['season'], autopct='%1.1f%%')
plt.title('My Pie Chart')
plt.show()

# %%
# Sample data
data = sns.load_dataset("iris")

# Creating pie charts per category
g = sns.catplot(data=data, kind="count", col="species", palette="Set1", height=4, aspect=0.7)
g.set_axis_labels("Species", "Count")

# Displaying the plot
g.set_titles("{col_name}")
g.set_xticklabels(rotation=90)
g.fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-2a844936c304> in <module>
#       3
#       4 # Creating pie charts per category
# ----> 5 g = sns.catplot(data=data, kind="count", col="species", palette="Set1", height=4, aspect=0.7)
#       6 g.set_axis_labels("Species", "Count")
#       7
#
# ~\Anaconda\lib\site-packages\seaborn\categorical.py in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3169             x_, y_, orient = x, x, "v"
#    3170         else:
# -> 3171             raise ValueError("Either `x` or `y` must be None for kind='count'")
#    3172     else:
#    3173         x_, y_ = x, y
#
# ...
