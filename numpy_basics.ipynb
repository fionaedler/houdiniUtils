# %%
# !conda activate houdinienv

# %%
import numpy as np
import pandas as pd

# %%
series = pd.Series(["amy", "Carl", "Sam"])
series
# Out:
# 0     amy
# 1    Carl
# 2     Sam
# dtype: object

# %%
maps = pd.Series(["Red", "White","Green", "Blue"])
assets = pd.Series(["Barrel", "Tree", "House", "Character"])

# %%
prod_data = pd.DataFrame({"Maps":maps, "Assets":assets})
prod_data
# Out:
#     Maps     Assets
# 0    Red     Barrel
# 1  White       Tree
# 2  Green      House
# 3   Blue  Character

# %%
sentiment_ds = pd.read_csv("data_sets/sentimentdataset.csv")

# %%
sentiment_ds.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout!                  Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
sentiment_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    732 non-null    int64
#  1   Unnamed: 0.1  732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
sentiment_ds.dtypes
# Out:
# Unnamed: 0        int64
# Unnamed: 0.1      int64
# Text             object
# Sentiment        object
# Timestamp        object
# User             object
# Platform         object
# Hashtags         object
# Retweets        float64
# Likes           float64
# Country          object
# Year              int64
# Month             int64
# Day               int64
# Hour              int64
# dtype: object

# %%
sentiment_ds.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Text', 'Sentiment', 'Timestamp', 'User',
#        'Platform', 'Hashtags', 'Retweets', 'Likes', 'Country', 'Year', 'Month',
#        'Day', 'Hour'],
#       dtype='object')

# %%
sentiment_ds["Text"]
# Out:
# 0       Enjoying a beautiful day at the park!        ...
# 1       Traffic was terrible this morning.           ...
# 2       Just finished an amazing workout!
# 3       Excited about the upcoming weekend getaway!  ...
# 4       Trying out a new recipe for dinner tonight.  ...
#                              ...
# 727    Collaborating on a science project that receiv...
# 728    Attending a surprise birthday party organized ...
# 729    Successfully fundraising for a school charity ...
# 730    Participating in a multicultural festival, cel...
# 731    Organizing a virtual talent show during challe...
# Name: Text, Length: 732, dtype: object

# %%
sentiment_ds.index
# Out:
# RangeIndex(start=0, stop=732, step=1)

# %%
sentiment_ds.describe()
# Out:
#        Unnamed: 0  Unnamed: 0.1    Retweets       Likes         Year  \
# count  732.000000    732.000000  732.000000  732.000000   732.000000
# mean   366.464481    369.740437   21.508197   42.901639  2020.471311
# std    211.513936    212.428936    7.061286   14.089848     2.802285
# min      0.000000      0.000000    5.000000   10.000000  2010.000000
# 25%    183.750000    185.750000   17.750000   34.750000  2019.000000
# 50%    366.500000    370.500000   22.000000   43.000000  2021.000000
# 75%    549.250000    553.250000   25.000000   50.000000  2023.000000
# max    732.000000    736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %%
sentiment_ds["Retweets"].mean()
# Out:
# 21.508196721311474

# %%
sentiment_ds.loc[3]
# Out:
# Unnamed: 0                                                      3
# Unnamed: 0.1                                                    3
# Text             Excited about the upcoming weekend getaway!  ...
# Sentiment                                              Positive
# Timestamp                                     2023-01-15 18:20:00
# User                                                AdventureX
# Platform                                                Facebook
# Hashtags                #Travel #Adventure
# Retweets                                                        8
# Likes                                                          15
# Country                                                 UK
# Year                                                         2023
# Month                                                           1
# Day                                                            15
# Hour                                                           18
# ...

# %%
sentiment_ds[sentiment_ds["Retweets"] > 15.0]
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 2             2             2
# 5             5             5
# 8             8             8
# 9             9             9
# 10           10            10
# ..          ...           ...
# 727         728           732
# 728         729           733
# 729         730           734
# 730         731           735
# 731         732           736
#
#                                                   Text    Sentiment  \
# 2     Just finished an amazing workout!                  Positive
# 5     Feeling grateful for the little things in lif...   Positive
# 8     Political discussions heating up on the timel...   Negative
# 9     Missing summer vibes and beach days.         ...   Neutral
# 10    Just published a new blog post. Check it out!...   Positive
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
pd.crosstab(sentiment_ds["Country"], sentiment_ds["Retweets"])
# Out:
# Retweets             5.0   7.0   8.0   9.0   10.0  11.0  12.0  13.0  14.0  \
# Country
#  Australia              0     0     0     0     2     0     3     0     0
#  Australia              0     0     0     0     0     0     0     0     0
#  Australia              0     0     0     0     0     0     0     0     0
#  Australia              0     0     2     0     1     0     1     0     3
#  Australia              0     1     1     0     0     0     1     0     0
# ...                   ...   ...   ...   ...   ...   ...   ...   ...   ...
#  USA                    1     0     0     0     4     0     3     1     0
#  USA                    0     0     1     0     0     0     0     0     0
#  USA                    0     0     0     0     0     0     0     0     0
#  USA                    0     0     0     0     0     0     0     0     0
# USA                     0     0     0     0     0     0     0     0     0
#
# ...

# %%
sentiment_ds.groupby(["Platform"]).sum()
# Out:
#              Unnamed: 0  Unnamed: 0.1  Retweets    Likes    Year  Month   Day  \
# Platform
#  Facebook         83211         83962    4844.0   9672.0  466719   1414  3850
#  Instagram        95929         96782    5831.0  11633.0  521301   1608  3905
#  Twitter          66419         66931    2918.0   5809.0  258667    888  1848
#  Twitter          22693         22975    2151.0   4290.0  232298    572  1741
#
#              Hour
# Platform
#  Facebook    3647
#  Instagram   4043
#  Twitter     2110
#  Twitter     1562

# %%
sentiment_ds["Retweets and Likes"] = sentiment_ds["Retweets"] + sentiment_ds["Likes"]

# %%
sentiment_ds
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 0             0             0
# 1             1             1
# 2             2             2
# 3             3             3
# 4             4             4
# ..          ...           ...
# 727         728           732
# 728         729           733
# 729         730           734
# 730         731           735
# 731         732           736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout!                  Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
sentiment_ds["Retweets"] = sentiment_ds["Retweets"].astype(np.int16)

# %%
sentiment_ds.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout!                  Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
sentiment_ds.dtypes
# Out:
# Unnamed: 0              int64
# Unnamed: 0.1            int64
# Text                   object
# Sentiment              object
# Timestamp              object
# User                   object
# Platform               object
# Hashtags               object
# Retweets                int16
# Likes                 float64
# Country                object
# Year                    int64
# Month                   int64
# Day                     int64
# Hour                    int64
# Retweets and Likes    float64
# dtype: object

# %%
sentiment_ds["Hashtags"] = sentiment_ds["Hashtags"].str.replace("#","")

# %%
sentiment_ds.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout!                  Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                    Hashtags  Retweets  Likes       Country  \
# ...

# %%
sentiment_ds[(sentiment_ds["Retweets"] > 20) & (sentiment_ds["Country"] == "USA")]
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 10           10            10
# 18           18            18
# 33           34            35
# 39           40            41
# 128         129           131
#
#                                                   Text        Sentiment  \
# 10    Just published a new blog post. Check it out!...       Positive
# 18    Attending a virtual conference on AI.        ...       Neutral
# 33    Feeling inspired after attending a workshop. ...       Positive
# 39    Excited about the upcoming gaming tournament....       Positive
# 128   Empowerment through learning and personal gro...   Empowerment
#
#                Timestamp               User     Platform  \
# 10   2023-01-17 15:15:00      BloggerX        Instagram
# 18   2023-01-20 11:30:00     TechConference    Facebook
# 33   2023-01-26 09:45:00   WorkshopAttendee   Instagram
# 39   2023-01-28 09:00:00   GamingEnthusiast   Instagram
# 128  2014-07-20 11:30:00   GrowthSeeker       Instagram
#
# ...

# %%
sentiment_ds["Retweets"].plot()

# %%
sentiment_ds["Likes"].hist()
